# %%
import pandas as pd
import time
from datetime import datetime
from pandas import ExcelWriter
import os
import xml.dom.minidom

pd.__version__
# Out:
# '1.0.0'

# %%
class JmeterScenarioSetup:
    def __init__(self,scenarioconfigFilePath,jmetertestplanFilePath):
        'Read scenarioconfigFil'
        self.scenarioconfigFilePath=scenarioconfigFilePath
        self.scenarioconfigColumns = ['ScriptName','ThisGroupWillStartWith_Threads','FirstWaitFor_Seconds','ThenStartWIth_Threads','NextAdd_Thread','Every_Seconds','UsingRampUp_Seconds','ThenHoldLoadFor_Seconds','FinallyStop_Thread','Every_Second']
        self.df_scenarioconfig=pd.read_csv(self.scenarioconfigFilePath,usecols=self.scenarioconfigColumns,dtype={'label':'category'})
        'Read Jmeter Test Plan'
        self.jmetertestplanFilePath=jmetertestplanFilePath
        
    def ScenarioSettings(self):
        #self.df_scenarioconfig.set_index('ScriptName',inplace=True)
        return self.df_scenarioconfig
    
    def JmeterTestPlan(self):
        jmxparse=xml.dom.minidom.parse(self.jmetertestplanFilePath)
        group=jmxparse.documentElement
        print(group)
        
        
        SteppingThreadGroups=group.getElementsByTagName('kg.apc.jmeter.threads.SteppingThreadGroup')
        iterator=0
        for SteppingThreadGroup in SteppingThreadGroups:
            threadgroupName=SteppingThreadGroup.getAttribute("testname")
            if threadgroupName=='jp@gc - Stepping Thread Group (deprecated)':
                SteppingThreadGroup.setAttribute('testname', self.df_scenarioconfig.iloc[iterator,0])
            iterator=iterator+1

        'To update the User and Ramup details'
        stringProps=group.getElementsByTagName('stringProp')
        rownum=0
        for stringProp in stringProps:
            cor_value=stringProp.getAttribute("name")
            
            'Note Dont change the below if equence bcz it should be match with jmx sequence'
            if cor_value=='ThreadGroup.num_threads':              
                stringProp.firstChild.data=self.df_scenarioconfig.iloc[rownum,1]#ThisGroupWillStartWith_Threads_D
                print("ThreadGroup.num_threads:"+str(rownum))
            if cor_value=='Threads initial delay':
                stringProp.firstChild.data=self.df_scenarioconfig.iloc[rownum,2]#FirstWaitFor_Seconds_D
                print("Threads initial delay:"+str(rownum))
            if cor_value=='Start users count':
                stringProp.firstChild.data=self.df_scenarioconfig.iloc[rownum,5]#NextAdd_Thread_D
                print("Start users count:"+str(rownum))
            if cor_value=='Start users count burst':
                stringProp.firstChild.data=self.df_scenarioconfig.iloc[rownum,3]#ThenStartWIth_Threads_D
                print("Start users count burst:"+str(rownum))           
            if cor_value=='Start users period':
                stringProp.firstChild.data=self.df_scenarioconfig.iloc[rownum,4]#Every_Seconds
                print("Start users period:"+str(rownum))
            if cor_value=='Stop users count':
                stringProp.firstChild.data=self.df_scenarioconfig.iloc[rownum,8]#FinallyStop_Thread
                print("Stop users count:"+str(rownum)) 
            if cor_value=='Stop users period':
                stringProp.firstChild.data=self.df_scenarioconfig.iloc[rownum,9]#Every_Second
                print("Stop users period:"+str(rownum)) 
            if cor_value=='flighttime':
                stringProp.firstChild.data=self.df_scenarioconfig.iloc[rownum,7]#ThenHoldLoadFor_Seconds_D
                print("flighttime:"+str(rownum))
            if cor_value=='rampUp':
                stringProp.firstChild.data=self.df_scenarioconfig.iloc[rownum,6]#UsingRampUp_Seconds
                print("rampUp:"+str(rownum))          
            
            
                rownum=rownum+1
                
        jmxparse.toprettyxml()
        print(jmxparse)
        jmxparse.writexml(open('D:\\Projects\\AllSec\\Scripts\\Scenario\\zSmokeTest_21Mar.jmx','w'))
                
         
        

        
        
        
        
obj1=JmeterScenarioSetup('D:\\Projects\\AllSec\\Scripts\\Scenario\\ScenarioConfig.csv','D:\\Projects\\AllSec\\Scripts\\Scenario\\SmokeTest_21Mar.jmx')
obj1.JmeterTestPlan()
obj1.ScenarioSettings()
# Out:
# <DOM Element: jmeterTestPlan at 0x1cfdbdc5d68>
# ThreadGroup.num_threads:0
# Threads initial delay:0
# Start users count:0
# Start users count burst:0
# Start users period:0
# Stop users count:0
# Stop users period:0
# flighttime:0
# rampUp:0
# ThreadGroup.num_threads:1
# Threads initial delay:1
# Start users count:1
# Start users count burst:1
# Start users period:1
# Stop users count:1
# Stop users period:1
# flighttime:1
# rampUp:1
# ThreadGroup.num_threads:2
# Threads initial delay:2
# Start users count:2
# Start users count burst:2
# Start users period:2
# Stop users count:2
# Stop users period:2
# flighttime:2
# rampUp:2
# ThreadGroup.num_threads:3
# Threads initial delay:3
# Start users count:3
# Start users count burst:3
# Start users period:3
# Stop users count:3
# Stop users period:3
# flighttime:3
# rampUp:3
# ThreadGroup.num_threads:4
# Threads initial delay:4
# Start users count:4
# Start users count burst:4
# Start users period:4
# Stop users count:4
# Stop users period:4
# flighttime:4
# rampUp:4
# ThreadGroup.num_threads:5
# Threads initial delay:5
# Start users count:5
# Start users count burst:5
# Start users period:5
# Stop users count:5
# Stop users period:5
# flighttime:5
# rampUp:5
# ThreadGroup.num_threads:6
# Threads initial delay:6
# Start users count:6
# Start users count burst:6
# Start users period:6
# Stop users count:6
# Stop users period:6
# flighttime:6
# rampUp:6
# ThreadGroup.num_threads:7
# Threads initial delay:7
# Start users count:7
# Start users count burst:7
# Start users period:7
# Stop users count:7
# Stop users period:7
# flighttime:7
# rampUp:7
# ThreadGroup.num_threads:8
# Threads initial delay:8
# Start users count:8
# Start users count burst:8
# Start users period:8
# Stop users count:8
# Stop users period:8
# flighttime:8
# rampUp:8
# ThreadGroup.num_threads:9
# Threads initial delay:9
# Start users count:9
# Start users count burst:9
# Start users period:9
# Stop users count:9
# Stop users period:9
# flighttime:9
# rampUp:9
# ThreadGroup.num_threads:10
# Threads initial delay:10
# Start users count:10
# Start users count burst:10
# Start users period:10
# Stop users count:10
# Stop users period:10
# flighttime:10
# rampUp:10
# ThreadGroup.num_threads:11
# Threads initial delay:11
# Start users count:11
# Start users count burst:11
# Start users period:11
# Stop users count:11
# Stop users period:11
# flighttime:11
# rampUp:11
# ThreadGroup.num_threads:12
# Threads initial delay:12
# Start users count:12
# Start users count burst:12
# Start users period:12
# Stop users count:12
# Stop users period:12
# flighttime:12
# rampUp:12
# ThreadGroup.num_threads:13
# Threads initial delay:13
# Start users count:13
# Start users count burst:13
# Start users period:13
# Stop users count:13
# Stop users period:13
# flighttime:13
# rampUp:13
# ThreadGroup.num_threads:14
# Threads initial delay:14
# Start users count:14
# Start users count burst:14
# Start users period:14
# Stop users count:14
# Stop users period:14
# flighttime:14
# rampUp:14
# ThreadGroup.num_threads:15
# Threads initial delay:15
# Start users count:15
# Start users count burst:15
# Start users period:15
# Stop users count:15
# Stop users period:15
# flighttime:15
# rampUp:15
# ThreadGroup.num_threads:16
# Threads initial delay:16
# Start users count:16
# Start users count burst:16
# Start users period:16
# Stop users count:16
# Stop users period:16
# flighttime:16
# rampUp:16
# ThreadGroup.num_threads:17
# Threads initial delay:17
# Start users count:17
# Start users count burst:17
# Start users period:17
# Stop users count:17
# Stop users period:17
# flighttime:17
# rampUp:17
# <xml.dom.minidom.Document object at 0x000001CFDBDC6FA8>
#                                            ScriptName  \
# 0                       SCN001_EmployeeAttendanceview
# 1                  SCN002_EmployeeFlexRosterShiftView
# 2                         SCN003_Employee_KMCapturing
# 3                     SCN004_SupervisorAttendanceView
# 4           SCN05_SupervisorFlexiCategoryBookedstatus
# 5   SCN006_StationMaster_FlexiCategory _LiveDashboard
# 6            SCN07_StationMasterFlexiBookedStatusView
# 7    SCN008_TeamLead_FlexiCategory_Bookedshiftsstatus
# 8                       SCN010_AMHR_Attendance_Upload
# 9                    SCN011_HRBP_AttendanceCorrection
# 10                           SCN12_HRBP_LiveDashboard
# 11               SCN013_HRBP_RosterFlexiLiveDashBoard
# 12                 SCN14_HRBP_AttendanceDetail Report
# 13             SCN015_HRBP_AttendanceCapturingDetails
# 14                       SCN016_HRBP_BasicInfo_Report
# 15           SCN017_HRBP_NewJoinerandSeparationReport
# 16                               SCN18_HRBP_OT_Report
# 17                     SCN019_HRBP_LeaveBalanceReport
#
#     ThisGroupWillStartWith_Threads  FirstWaitFor_Seconds  \
# 0                                2                     0
# 1                                2                    15
# 2                                2                    30
# 3                                2                    45
# 4                                2                    60
# 5                                2                    75
# 6                                2                    90
# 7                                2                   105
# 8                                2                   120
# 9                                2                   135
# 10                               2                   150
# 11                               2                   165
# 12                               2                   180
# 13                               2                   195
# 14                               2                   210
# 15                               2                   225
# 16                               2                   240
# 17                               2                   255
#
#     ThenStartWIth_Threads  Every_Seconds  NextAdd_Thread  UsingRampUp_Seconds  \
# 0                       2              0               0                   10
# 1                       2              0               0                   10
# 2                       2              0               0                   10
# 3                       2              0               0                   10
# 4                       2              0               0                   10
# 5                       2              0               0                   10
# 6                       2              0               0                   10
# 7                       2              0               0                   10
# 8                       2              0               0                   10
# 9                       2              0               0                   10
# 10                      2              0               0                   10
# 11                      2              0               0                   10
# 12                      2              0               0                   10
# 13                      2              0               0                   10
# 14                      2              0               0                   10
# 15                      2              0               0                   10
# 16                      2              0               0                   10
# 17                      2              0               0                   10
#
#     ThenHoldLoadFor_Seconds  FinallyStop_Thread  Every_Second
# 0                      3610                   2            10
# 1                      3610                   2            10
# 2                      3610                   2            10
# 3                      3610                   2            10
# 4                      3610                   2            10
# 5                      3610                   2            10
# 6                      3610                   2            10
# 7                      3610                   2            10
# 8                      3610                   2            10
# 9                      3610                   2            10
# 10                     3610                   2            10
# 11                     3610                   2            10
# 12                     3610                   2            10
# 13                     3610                   2            10
# 14                     3610                   2            10
# 15                     3610                   2            10
# 16                     3610                   2            10
# 17                     3610                   2            10
